# %%
#pip install lxml
#pip install -U textblob

# %% [markdown]
# # WEB SCRAPING and SENTIMENTAL ANALYSYS

# %% [markdown]
# From a eu dairy milk forecast article, I will analyse if the article is sentimental positive or negative. F Beautiful Soup ill be used to extract the article form the web.
#
# Analysis will be run paragraph by paragraph using multiple techniques. the mean of the paragraphs will be done to determine if the overall article is positive or negative.

# %% [markdown]
# # 0 Web Scraping

# %%
import requests

from bs4                               import BeautifulSoup
from textblob                          import TextBlob
from nltk.corpus                       import stopwords
from nltk.stem                         import PorterStemmer
from textblob                          import Word
from sklearn.feature_extraction.text   import TfidfVectorizer
from sklearn.feature_extraction.text   import CountVectorizer


import pandas            as pd
import numpy             as np

import warnings
warnings.filterwarnings("ignore")

# %%
#import article using beautiful soup
url = 'http://foodingredientsfirst.com/news/eu-dairy-industry-forecasts-uncertain-2023-as-milk-availability-is-no-longer-abundant.html'
r = requests.get(url)
s = BeautifulSoup(r.content, 'html.parser')
a = []
for text in s.find_all('p'):
    b = text.get_text()
    a.append(b)
print(a)
# Out:
# ['\r\n                                        By continuing to browse our site you agree to our Privacy & Cookie Policy.\r\n                                         > Privacy & Cookie Policy I Agree\n', 'FREE NEWSLETTER', '13 Dec 2022 --- European dairy trading body Eucolait underscores the moral necessity of the block sharing its milk supply, albeit scarce, via free market trade at a time when societies grapple with post-pandemic headwinds, rampant inflation, supply chain shocks and the ongoing war in Ukraine.', '13 Dec 2022 --- European dairy trading body Eucolait underscores the moral necessity of the block sharing its milk supply, albeit scarce, via free market trade at a time when societies grapple with post-pandemic headwinds, rampant inflation, supply chain shocks and the ongoing war in Ukraine.', 'Despite the EU milk industry facing declining volumes, trade experts call for the EU to increase the output of milk saying that sustainability targets should not come with reduced outputs. Flagging how production might be a more important issue than trade restrictions. \xa0', 'The EU exports 20% of its milk solids and despite its limited supply, the bloc “has a duty to contribute to global food security,” according to Eucolait.', 'Redistributing better milk exports might help contribute to food security.', 'Jukka Likitalo, secretary General of Eucolait, tells FoodIngredientsFirst, that 2023 is shaping up to be uncertain for dairy.', 'He notes that while dairy prices have gone down in the last few months, there is still uncertainty and volatility ahead for the dairy markets.', '“Sentiment has weakened and prices have come down considerably over the last months as EU milk production was stronger than expected and there are some question marks on the consumption side due to the inflationary pressures and economic anxiety. We do not do price forecasts but my feeling is we have entered a new era where milk is no longer available in abundance, while global dairy consumption continues to grow,” explains Likitalo.', '“There is no shortage of uncertainty factors however: energy and other input costs, generational renewal in dairy farming, inflation, geopolitical developments, demand outlook in the main import market China, environmental regulations and changing consumer preferences just to name a few,” he continues. \xa0\xa0', 'Likitalo explains how the EU must be sensible with who it partners in the future, to avoid over dependence on unreliable partners like Russia or work too much in \xa0one big market, such as China.', 'Likitalo explains how the EU must be sensible with who it partners in the future, to avoid over dependence on unreliable partners like Russia.“We need to produce more”The trade body flags how dairy consumption is “inadequate” in large parts of the world, as many countries can’t meet their dairy necessities independently. This prompts a need for more overall milk production.\xa0', '“A sustainable food system uses scarce natural resources as efficiently and effectively as possible. In the face of the dual challenge of feeding a growing global population and mitigating climate change, we need to produce more, from less and with fewer adverse impacts and in places and climates best adapted for this. As such, there can be no food security without open, rule-based trade,” the trade body explains.', '“The enhanced sustainability of the European dairy sector should not go hand-in-hand with a declining output.”', '“Trade in its most basic essence connects surpluses with deficits and helps countries or regions play to their strengths.”\xa0', 'Internally, in the EU, Likitalo highlights that “it is crucial from a food security standpoint that the single market remains operational during crisis situations,” to avoid shortages and supply disparities.\xa0', 'Global trade on the riseEucolait explains that despite international economic woes that affect demand, global trade of dairy increased 2.7% in Q3. However this 2022 will “lik ...

# %% [markdown]
# # 1 Sentimental Analysis

# %%
# Transform list into a dataframe
text = pd.DataFrame(a, columns=['paragraph'])
text
# Out:
#                                             paragraph
# 0   \r\n                                        By...
# 1                                     FREE NEWSLETTER
# 2   13 Dec 2022 --- European dairy trading body Eu...
# 3   13 Dec 2022 --- European dairy trading body Eu...
# 4   Despite the EU milk industry facing declining ...
# 5   The EU exports 20% of its milk solids and desp...
# 6   Redistributing better milk exports might help ...
# 7   Jukka Likitalo, secretary General of Eucolait,...
# 8   He notes that while dairy prices have gone dow...
# 9   “Sentiment has weakened and prices have come d...
# 10  “There is no shortage of uncertainty factors h...
# 11  Likitalo explains how the EU must be sensible ...
# 12  Likitalo explains how the EU must be sensible ...
# 13  “A sustainable food system uses scarce natural...
# 14  “The enhanced sustainability of the European d...
# 15  “Trade in its most basic essence connects surp...
# 16  Internally, in the EU, Likitalo highlights tha...
# 17  Global trade on the riseEucolait explains that...
# 18  Notably, weak Chinese dairy demand explains th...
# 19  Dairy imports in China are down 20% year-on-ye...
# 20  Dairy commodity prices dipIn the UK consumers ...
# 21  FAO says that there is an “increased export av...
# 22  Nevertheless, consumers are paying considerabl...
# 23  Kerry Dairy Ireland revealed in its Q3 report ...
# 24  European Dairy giant FrieslandCampina’s Food &...
# 25  Danish-Swedish multinational cooperative Arla ...
# 26  “Global milk supply levels continue to stabili...
# 27  “The last year has brought inflationary challe...
# 28  However, general cheese demand, as in previous...
# 29  Cheese is becoming a coveted commodity, with s...
# 30                                    By Marc Cervera
# 31  \r\n                                          ...
# 32                              FOOD INGREDIENTS NEWS
# 33  \nThe corruption court at the central Jakarta ...
# 34                              FOOD INGREDIENTS NEWS
# 35  \nFood inflation is one of the most significan...
# 36                              FOOD INGREDIENTS NEWS
# 37  \nA partnership between the EU and the Food an...
# 38                              FOOD INGREDIENTS NEWS
# 39  \nChina is to relax its testing on imported fr...
# 40                              FOOD INGREDIENTS NEWS
# 41  \nAs 2023 begins, countries continue their att...
# 42                               FoodIngredientsFirst
# 43                            Mail sent successfully.
# 44                                     Mail not sent.
# 45  Subscribe now to our free newsletters to stay ...
# 46  \nFoodIngredientsFirst.com is the leading inte...

# %%
# drop duplicates as soom paragraphs were pushed twice like 2/3, 11/12, 33/34/36/40 ...
text = text.drop_duplicates()

# %% [markdown]
# ## 1.1 Number of Words

# %%
# slit based on space
text['word_count'] = text['paragraph'].apply(lambda x: len(str(x).split(" ")))

# disclose df with text / number of words per paragraph
text[['paragraph','word_count']]
# Out:
#                                             paragraph  word_count
# 0   \r\n                                        By...         101
# 1                                     FREE NEWSLETTER           2
# 2   13 Dec 2022 --- European dairy trading body Eu...          46
# 4   Despite the EU milk industry facing declining ...          43
# 5   The EU exports 20% of its milk solids and desp...          27
# 6   Redistributing better milk exports might help ...          10
# 7   Jukka Likitalo, secretary General of Eucolait,...          18
# 8   He notes that while dairy prices have gone dow...          25
# 9   “Sentiment has weakened and prices have come d...          72
# 10  “There is no shortage of uncertainty factors h...          43
# 11  Likitalo explains how the EU must be sensible ...          35
# 12  Likitalo explains how the EU must be sensible ...          60
# 13  “A sustainable food system uses scarce natural...          68
# 14  “The enhanced sustainability of the European d...          16
# 15  “Trade in its most basic essence connects surp...          19
# 16  Internally, in the EU, Likitalo highlights tha...          30
# 17  Global trade on the riseEucolait explains that...          44
# 18  Notably, weak Chinese dairy demand explains th...          44
# 19  Dairy imports in China are down 20% year-on-ye...          53
# 20  Dairy commodity prices dipIn the UK consumers ...          62
# 21  FAO says that there is an “increased export av...          11
# 22  Nevertheless, consumers are paying considerabl...          35
# 23  Kerry Dairy Ireland revealed in its Q3 report ...          41
# 24  European Dairy giant FrieslandCampina’s Food &...          20
# 25  Danish-Swedish multinational cooperative Arla ...          27
# 26  “Global milk supply levels continue to stabili...          49
# 27  “The last year has brought inflationary challe...          43
# 28  However, general cheese demand, as in previous...          38
# 29  Cheese is becoming a coveted commodity, with s...          19
# 30                                    By Marc Cervera           3
# 31  \r\n                                          ...         113
# 32                              FOOD INGREDIENTS NEWS           3
# 33  \nThe corruption court at the central Jakarta ...          27
# 35  \nFood inflation is one of the most significan...          28
# 37  \nA partnership between the EU and the Food an...          27
# 39  \nChina is to relax its testing on imported fr...          27
# 41  \nAs 2023 begins, countries continue their att...          27
# 42                               FoodIngredientsFirst           1
# 43                            Mail sent successfully.           3
# 44                                     Mail not sent.           3
# 45  Subscribe now to our free newsletters to stay ...          26
# 46  \nFoodIngredientsFirst.com is the leading inte...          76

# %%
# drop paragraphs that do not add meaning
text.drop([1, 42, 43, 44,45], axis=0, inplace=True)
text.shape
# Out:
# (37, 2)

# %% [markdown]
# ## 1.2 Number of characters

# %%
# count the number of characters
text['char_count'] = text['paragraph'].str.len()

# disclose df with text / number of letters per paragraph
text[['paragraph','char_count']].head()
# Out:
#                                            paragraph  char_count
# 0  \r\n                                        By...         193
# 2  13 Dec 2022 --- European dairy trading body Eu...         293
# 4  Despite the EU milk industry facing declining ...         271
# 5  The EU exports 20% of its milk solids and desp...         153
# 6  Redistributing better milk exports might help ...          74

# %% [markdown]
# ## 1.3 Average Word Length

# %%
# define average number of letters per words
def avg_word(sentence):
  words = sentence.split()
  return (sum(len(word) for word in words)/len(words))

# %%
text['avg_word'] = text['paragraph'].apply(lambda x: avg_word(x))

# %%
# disclose df with text / avrage number of letters per word per paragraph
text[['paragraph','avg_word']].head()
# Out:
#                                            paragraph  avg_word
# 0  \r\n                                        By...  4.190476
# 2  13 Dec 2022 --- European dairy trading body Eu...  5.391304
# 4  Despite the EU milk industry facing declining ...  5.428571
# 5  The EU exports 20% of its milk solids and desp...  4.703704
# 6  Redistributing better milk exports might help ...  6.500000

# %% [markdown]
# ## 1.4 Number of stopwords
#
# **One of the first NLP steps is to remove stopwords**

# %%
# select english dictionary
stop = stopwords.words('english')

# %%
# find number of stopwords
text['stopwords'] = text['paragraph'].apply(lambda x: len([x for x in x.split() if x in stop]))
text[['paragraph','stopwords']].head()
# Out:
#                                            paragraph  stopwords
# 0  \r\n                                        By...          5
# 2  13 Dec 2022 --- European dairy trading body Eu...         11
# 4  Despite the EU milk industry facing declining ...         15
# 5  The EU exports 20% of its milk solids and desp...          9
# 6  Redistributing better milk exports might help ...          1

# %% [markdown]
# ## 1.5 Basic Pre-Processing
# **To obtain better features I will start by cleaning data using some basic pre-processing steps**

# %%
#avoids having multiple copies of the same word
text['paragraph'] = text['paragraph'].apply(lambda x: " ".join(x.lower() for x in x.split()))
text['paragraph'].head()
# Out:
# 0    by continuing to browse our site you agree to ...
# 2    13 dec 2022 --- european dairy trading body eu...
# 4    despite the eu milk industry facing declining ...
# 5    the eu exports 20% of its milk solids and desp...
# 6    redistributing better milk exports might help ...
# Name: paragraph, dtype: object

# %%
#remove punctuation, removing all instances of it will help us reduce the size of the training data.
text['paragraph'] = text['paragraph'].str.replace('[^\w\s]','')
text['paragraph'].head()
# Out:
# 0    by continuing to browse our site you agree to ...
# 2    13 dec 2022  european dairy trading body eucol...
# 4    despite the eu milk industry facing declining ...
# 5    the eu exports 20 of its milk solids and despi...
# 6    redistributing better milk exports might help ...
# Name: paragraph, dtype: object

# %%
#stop words (or commonly occurring words) should be removed from the text data
text['paragraph'] = text['paragraph'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
text['paragraph'].head()
# Out:
# 0    continuing browse site agree privacy cookie po...
# 2    13 dec 2022 european dairy trading body eucola...
# 4    despite eu milk industry facing declining volu...
# 5    eu exports 20 milk solids despite limited supp...
# 6    redistributing better milk exports might help ...
# Name: paragraph, dtype: object

# %%
# Commonly occured words were removed but it is as well possible to remove words that are often showing in our dataset just removed commonly occurring words in a general sense. We can also
# I will check the top 10 most used
freq = pd.Series(' '.join(text['paragraph']).split()).value_counts()[:10]
freq
# Out:
# dairy        24
# food         14
# prices       14
# milk         13
# trade        11
# eu            9
# demand        7
# year          7
# global        7
# countries     6
# dtype: int64

# %% [markdown]
# **I will not remove dairy as it is a very important word for the analysis**

# %%
#Now, let’s remove these words as their presence will not of any use in classification of our text data. 
freq = list(freq.index)
text['paragraph'] = text['paragraph'].apply(lambda x: " ".join(x for x in x.split() if x not in freq))
text['paragraph'].head()
# Out:
# 0    continuing browse site agree privacy cookie po...
# 2    13 dec 2022 european trading body eucolait und...
# 4    despite industry facing declining volumes expe...
# 5    exports 20 solids despite limited supply bloc ...
# 6    redistributing better exports might help contr...
# Name: paragraph, dtype: object

# %% [markdown]
# ## 1.6 Rare words removal
# **With most common words removed, I will remove the most rare as they can be considered noise**

# %%
freq = pd.Series(' '.join(text['paragraph']).split()).value_counts()[-10:]
freq
# Out:
# best           1
# climates       1
# places         1
# impacts        1
# adverse        1
# fewer          1
# change         1
# climate        1
# mitigating     1
# netherlands    1
# dtype: int64

# %%
freq = list(freq.index)
text['paragraph'] = text['paragraph'].apply(lambda x: " ".join(x for x in x.split() if x not in freq))
text['paragraph'].head()
# Out:
# 0    continuing browse site agree privacy cookie po...
# 2    13 dec 2022 european trading body eucolait und...
# 4    despite industry facing declining volumes expe...
# 5    exports 20 solids despite limited supply bloc ...
# 6    redistributing better exports might help contr...
# Name: paragraph, dtype: object

# %% [markdown]
# ## 1.7 Spelling correction
# **Spelling correction is usefull as well because it helps in reducing multiple copies of words. Considering that is a news story, this had been through this before publishing**

# %%
text['paragraph'].apply(lambda x: str(TextBlob(x).correct()))
# Out:
# 0     continuing brows site agree privacy cook polic...
# 2     13 dec 2022 european trading body eucolait und...
# 4     despite industry facing declining volumes expe...
# 5     exports 20 solids despite limited supply bloc ...
# 6     redistributing better exports might help contr...
# 7     julia likitalo secretary general eucolait tell...
# 8     notes gone last months still uncertainty volat...
# 9     sentiment weakened come considerably last mont...
# 10    shortage uncertainty factors however energy in...
# 11    likitalo explains must sensible partners futur...
# 12    likitalo explains must sensible partners futur...
# 13    sustainable system uses scarce natural resourc...
# 14    enhanced sustainability european sector go han...
# 15    basic essence connect surplus deficit helps re...
# 16    internally likitalo highlight crucial security...
# 17    riseeucolait explains despite international ec...
# 18    notably weak chinese explains fall internation...
# 19    imports china 20 yearonyear according agricult...
# 20    commodity didn up consumers seeing annual rise...
# 21        far says increased export availability europe
# 22    nevertheless consumers paying considerably fin...
# 23    merry ireland revealed qu report increased 366...
# 24    european giant frieslandcampinas beverage busi...
# 25    danishswedish multinational cooperative area f...
# 26    supply levels continue stability levels europe...
# 27    last brought inflationary challenges farmerown...
# 28    however general cheese previous months continu...
# 29    cheese becoming coveted commodity supermarket ...
# 30                                         mary cervera
# 31    contact editorial team please email us editori...
# 32                                      ingredient news
# 33    corruption court central makarka district cour...
# 35    inflation one significant topics 2023 gets und...
# 37    partnership agriculture organization united na...
# 39    china relax testing imported frozen chilled pr...
# 41    2023 begins continue attempts tame inflation s...
# 46    foodingredientsfirstcom leading international ...
# Name: paragraph, dtype: object

# %% [markdown]
# ## 1.8 Tokenization
# **This steps refers to dividing the text into a sequence of words or sentences. First transform everything into a blob and then
# converts into a series of words**

# %%
token =[]

for i in text.index:
    token.append(TextBlob(text['paragraph'][i]).words)
    
token
# Out:
# [WordList(['continuing', 'browse', 'site', 'agree', 'privacy', 'cookie', 'policy', 'privacy', 'cookie', 'policy', 'agree']),
#  WordList(['13', 'dec', '2022', 'european', 'trading', 'body', 'eucolait', 'underscores', 'moral', 'necessity', 'block', 'sharing', 'supply', 'albeit', 'scarce', 'via', 'free', 'market', 'time', 'societies', 'grapple', 'postpandemic', 'headwinds', 'rampant', 'inflation', 'supply', 'chain', 'shocks', 'ongoing', 'war', 'ukraine']),
#  WordList(['despite', 'industry', 'facing', 'declining', 'volumes', 'experts', 'call', 'increase', 'output', 'saying', 'sustainability', 'targets', 'come', 'reduced', 'outputs', 'flagging', 'production', 'might', 'important', 'issue', 'restrictions']),
#  WordList(['exports', '20', 'solids', 'despite', 'limited', 'supply', 'bloc', 'duty', 'contribute', 'security', 'according', 'eucolait']),
#  WordList(['redistributing', 'better', 'exports', 'might', 'help', 'contribute', 'security']),
#  WordList(['jukka', 'likitalo', 'secretary', 'general', 'eucolait', 'tells', 'foodingredientsfirst', '2023', 'shaping', 'uncertain']),
#  WordList(['notes', 'gone', 'last', 'months', 'still', 'uncertainty', 'volatility', 'ahead', 'markets']),
#  WordList(['sentiment', 'weakened', 'come', 'considerably', 'last', 'months', 'production', 'stronger', 'expected', 'question', 'marks', 'consumption', 'side', 'due', 'inflationary', 'pressures', 'economic', 'anxiety', 'price', 'forecasts', 'feeling', 'entered', 'new', 'era', 'longer', 'available', 'abundance', 'consumption', 'continues', 'grow', 'explains', 'likitalo']),
#  WordList(['shortage', 'uncertainty', 'factors', 'however', 'energy', 'input', 'costs', 'generational', 'renewal', 'farming', 'inflation', 'geopolitical', 'developments', 'outlook', 'main', 'import', 'market', 'china', 'environmental', 'regulations', 'changing', 'consumer', 'preferences', 'name', 'continues']),
#  WordList(['likitalo', 'explains', 'must', 'sensible', 'partners', 'future', 'avoid', 'dependence', 'unreliable', 'partners', 'like', 'russia', 'work', 'much', 'one', 'big', 'market', 'china']),
#  WordList(['likitalo', 'explains', 'must', 'sensible', 'partners', 'future', 'avoid', 'dependence', 'unreliable', 'partners', 'like', 'russiawe', 'need', 'produce', 'morethe', 'body', 'flags', 'consumption', 'inadequate', 'large', 'parts', 'world', 'many', 'cant', 'meet', 'necessities', 'independently', 'prompts', 'need', 'overall', 'production']),
#  WordList(['sustainable', 'system', 'uses', 'scarce', 'natural', 'resources', 'efficiently', 'effectively', 'possible', 'face', 'dual', 'challenge', 'feeding', 'growing', 'population', 'need', 'produce', 'less', 'adapted', 'security', 'without', 'open', 'rulebased', 'body', 'explains']),
#  WordList(['enhanced', 'sustainability', 'european', 'sector', 'go', 'handinhand', 'declining', 'output']),
#  WordList(['basic', 'essence', 'connects', 'surpluses', 'deficits', 'helps', 'regions', 'play', 'strengths']),
#  WordList(['internally', 'likitalo', 'highlights', 'crucial', 'security', 'standpoint', 'single', 'market', 'remains', 'operational', 'crisis', 'situations', 'avoid', 'shortages', 'supply', 'disparities']),
#  WordList(['riseeucolait', 'explains', 'despite', 'international', 'economic', 'woes', 'affect', 'increased', '27', 'q3', 'however', '2022', 'likely', 'mark', 'first', 'decline', 'cumulative', 'volumes', 'two', 'decades', 'expected', 'fall', '23']),
#  WordList(['notably', 'weak', 'chinese', 'explains', 'fall', 'internationally', 'nevertheless', 'asian', 'dynamic', 'led', 'indonesia', 'fastest', 'growing', 'market', 'world', 'like', 'saudi', 'arabia', 'philippines', 'also', 'stood', 'according', 'eucolait']),
#  WordList(['imports', 'china', '20', 'yearonyear', 'according', 'agriculture', 'horticulture', 'development', 'board', 'ahbd', 'ahbd', 'flags', 'lower', 'offered', 'relief', 'international', 'however', 'producers', 'negatively', 'affected', 'saw', 'fall', 'exports', 'asian', 'giant', '31', 'single']),
#  WordList(['commodity', 'dipin', 'uk', 'consumers', 'seeing', 'annual', 'rise', 'cpi', 'lowfat', '479', 'un', 'fao', 'price', 'index', 'showed', '12', 'decline', 'november', 'october', 'declining', 'fifth', 'consecutive', 'month', 'however', 'continue', '92', 'higher', 'one', 'ago', 'driven', 'inflationary', 'pressures', 'earlier']),
#  WordList(['fao', 'says', 'increased', 'export', 'availability', 'europe']),
#  WordList(['nevertheless', 'consumers', 'paying', 'considerably', 'finished', 'product', 'stores', 'globally', '92', 'commoditywise', 'uk', 'consumers', 'seeing', 'annual', 'rise', 'cpi', 'lowfat', '479']),
#  WordList(['kerry', 'ireland', 'revealed', 'q3', 'report', 'increased', '366', 'first', 'nine', 'months', 'significantly', 'outpacing', 'general', 'pricing', 'strategy', 'giant', 'increased', '106']),
#  WordList(['european', 'giant', 'frieslandcampinas', 'beverage', 'business', 'revealed', 'halfyear', 'results', 'boosted', 'high', 'butter', 'market']),
#  WordList(['danishswedish', 'multinational', 'cooperative', 'arla', 'foods', 'increased', 'eight', 'months', 'row', 'december', 'marking', 'first', 'month', 'since', 'march', 'without', 'price', 'increases']),
#  WordList(['supply', 'levels', 'continue', 'stabilize', 'levels', 'europe', 'increasing', 'commodity', 'including', 'yellow', 'cheese', 'butter', 'declined', 'previous', 'high', 'levels', 'october', 'outlook', 'negative', 'driven', 'continued', 'decline', 'commodity', 'says', 'arthur', 'fearnall', 'arla', 'foods', 'board', 'director']),
#  WordList(['last', 'brought', 'inflationary', 'challenges', 'farmerowners', 'teams', 'across', 'uk', 'worked', 'hard', 'deliver', 'significant', 'increases', 'conventional', 'organic', 'farmgate', 'price', 'throughout', 'adds', 'paul', 'savage', 'agriculture', 'director', 'arla', 'uk']),
#  WordList(['however', 'general', 'cheese', 'previous', 'months', 'continues', 'outpace', 'formilk', 'international', 'cheese', 'increased', 'underpinned', 'steady', 'import', 'less', 'buoyant', 'export', 'availability', 'major', 'producing', 'western', 'europe', 'says', 'fao']),
#  WordList(['cheese', 'becoming', 'coveted', 'commodity', 'supermarkets', 'uk', 'putting', 'security', 'tags', 'cheese', 'butter', 'products']),
#  WordList(['marc', 'cervera']),
#  WordList(['contact', 'editorial', 'team', 'please', 'email', 'us', 'editorialcnsmediacom']),
#  WordList(['ingredients', 'news']),
#  WordList(['corruption', 'court', 'central', 'jakarta', 'district', 'court', 'sentenced', 'former', 'director', 'general', 'ministry', 'head', 'countrys', 'commodity', 'read']),
#  WordList(['inflation', 'one', 'significant', 'topics', '2023', 'gets', 'underway', 'underscored', 'latest', 'data', 'uk', 'reveals', 'annual', 'growth', 'britains', 'read']),
#  WordList(['partnership', 'agriculture', 'organization', 'united', 'nations', 'fao', 'provide', 'us155', 'million', 'ensure', 'support', 'ukrainian', 'read']),
#  WordList(['china', 'relax', 'testing', 'imported', 'frozen', 'chilled', 'products', 'lowering', 'costs', 'exporters', 'confirmed', 'countrys', 'customs', 'authorities', 'state', 'read']),
#  WordList(['2023', 'begins', 'continue', 'attempts', 'tame', 'inflation', 'spain', 'us', 'states', 'reducing', 'vat', 'taxes', 'sacrificing', 'potential', 'tax', 'revenue', 'aiming', 'read']),
#  WordList(['foodingredientsfirstcom', 'leading', 'international', 'publisher', 'ingredients', 'product', 'development', 'platform', 'hosted', 'cns', 'media', 'bv', 'arnhem'])]

# %% [markdown]
# ## 1.9 Stemming
# **Tihs steps refers to the removal of suffices, like “ing”, “ly”, “s”...**

# %%
st = PorterStemmer()
text['paragraph'].apply(lambda x: " ".join([st.stem(word) for word in x.split()]))
# Out:
# 0     continu brows site agre privaci cooki polici p...
# 2     13 dec 2022 european trade bodi eucolait under...
# 4     despit industri face declin volum expert call ...
# 5     export 20 solid despit limit suppli bloc duti ...
# 6     redistribut better export might help contribut...
# 7     jukka likitalo secretari gener eucolait tell f...
# 8     note gone last month still uncertainti volatil...
# 9     sentiment weaken come consider last month prod...
# 10    shortag uncertainti factor howev energi input ...
# 11    likitalo explain must sensibl partner futur av...
# 12    likitalo explain must sensibl partner futur av...
# 13    sustain system use scarc natur resourc effici ...
# 14    enhanc sustain european sector go handinhand d...
# 15    basic essenc connect surplus deficit help regi...
# 16    intern likitalo highlight crucial secur standp...
# 17    riseeucolait explain despit intern econom woe ...
# 18    notabl weak chines explain fall intern neverth...
# 19    import china 20 yearonyear accord agricultur h...
# 20    commod dipin uk consum see annual rise cpi low...
# 21                   fao say increas export avail europ
# 22    nevertheless consum pay consider finish produc...
# 23    kerri ireland reveal q3 report increas 366 fir...
# 24    european giant frieslandcampina beverag busi r...
# 25    danishswedish multin cooper arla food increas ...
# 26    suppli level continu stabil level europ increa...
# 27    last brought inflationari challeng farmerown t...
# 28    howev gener chees previou month continu outpac...
# 29    chees becom covet commod supermarket uk put se...
# 30                                         marc cervera
# 31    contact editori team pleas email us editorialc...
# 32                                         ingredi news
# 33    corrupt court central jakarta district court s...
# 35    inflat one signific topic 2023 get underway un...
# 37    partnership agricultur organ unit nation fao p...
# 39    china relax test import frozen chill product l...
# 41    2023 begin continu attempt tame inflat spain u...
# 46    foodingredientsfirstcom lead intern publish in...
# Name: paragraph, dtype: object

# %% [markdown]
# ## 1.10 Lemmatization
# **Lemmatization is a more effective option than stemming because it converts the word into its
# root word, rather than just stripping the suffices**

# %%
text['paragraph'] = text['paragraph'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
text['paragraph'].head()
# Out:
# 0    continuing browse site agree privacy cookie po...
# 2    13 dec 2022 european trading body eucolait und...
# 4    despite industry facing declining volume exper...
# 5    export 20 solid despite limited supply bloc du...
# 6    redistributing better export might help contri...
# Name: paragraph, dtype: object

# %% [markdown]
# ## 1.11 Advance Text Processing
# **N-grams are the combination of multiple words used together. Ngrams with N=1 are called
# unigrams.**

# %%
adv =[]

for i in text.index:
    adv.append(TextBlob(text['paragraph'][i]).ngrams(3))
    
adv
# Out:
# [[WordList(['continuing', 'browse', 'site']),
#   WordList(['browse', 'site', 'agree']),
#   WordList(['site', 'agree', 'privacy']),
#   WordList(['agree', 'privacy', 'cookie']),
#   WordList(['privacy', 'cookie', 'policy']),
#   WordList(['cookie', 'policy', 'privacy']),
#   WordList(['policy', 'privacy', 'cookie']),
#   WordList(['privacy', 'cookie', 'policy']),
#   WordList(['cookie', 'policy', 'agree'])],
#  [WordList(['13', 'dec', '2022']),
#   WordList(['dec', '2022', 'european']),
#   WordList(['2022', 'european', 'trading']),
#   WordList(['european', 'trading', 'body']),
#   WordList(['trading', 'body', 'eucolait']),
#   WordList(['body', 'eucolait', 'underscore']),
#   WordList(['eucolait', 'underscore', 'moral']),
#   WordList(['underscore', 'moral', 'necessity']),
#   WordList(['moral', 'necessity', 'block']),
#   WordList(['necessity', 'block', 'sharing']),
#   WordList(['block', 'sharing', 'supply']),
#   WordList(['sharing', 'supply', 'albeit']),
#   WordList(['supply', 'albeit', 'scarce']),
#   WordList(['albeit', 'scarce', 'via']),
#   WordList(['scarce', 'via', 'free']),
#   WordList(['via', 'free', 'market']),
#   WordList(['free', 'market', 'time']),
#   WordList(['market', 'time', 'society']),
#   WordList(['time', 'society', 'grapple']),
#   WordList(['society', 'grapple', 'postpandemic']),
#   WordList(['grapple', 'postpandemic', 'headwind']),
#   WordList(['postpandemic', 'headwind', 'rampant']),
#   WordList(['headwind', 'rampant', 'inflation']),
#   WordList(['rampant', 'inflation', 'supply']),
#   WordList(['inflation', 'supply', 'chain']),
#   WordList(['supply', 'chain', 'shock']),
#   WordList(['chain', 'shock', 'ongoing']),
#   WordList(['shock', 'ongoing', 'war']),
#   WordList(['ongoing', 'war', 'ukraine'])],
#  [WordList(['despite', 'industry', 'facing']),
#   WordList(['industry', 'facing', 'declining']),
#   WordList(['facing', 'declining', 'volume']),
#   WordList(['declining', 'volume', 'expert']),
#   WordList(['volume', 'expert', 'call']),
#   WordList(['expert', 'call', 'increase']),
#   WordList(['call', 'increase', 'output']),
#   WordList(['increase', 'output', 'saying']),
#   WordList(['output', 'saying', 'sustainability']),
#   WordList(['saying', 'sustainability', 'target']),
#   WordList(['sustainability', 'target', 'come']),
#   WordList(['target', 'come', 'reduced']),
#   WordList(['come', 'reduced', 'output']),
#   WordList(['reduced', 'output', 'flagging']),
#   WordList(['output', 'flagging', 'production']),
#   WordList(['flagging', 'production', 'might']),
#   WordList(['production', 'might', 'important']),
#   WordList(['might', 'important', 'issue']),
#   WordList(['important', 'issue', 'restriction'])],
#  [WordList(['export', '20', 'solid']),
#   WordList(['20', 'solid', 'despite']),
#   WordList(['solid', 'despite', 'limited']),
#   WordList(['despite', 'limited', 'supply']),
#   WordList(['limited', 'supply', 'bloc']),
#   WordList(['supply', 'bloc', 'duty']),
#   WordList(['bloc', 'duty', 'contribute']),
#   WordList(['duty', 'contribute', 'security']),
#   WordList(['contribute', 'security', 'according']),
#   WordList(['security', 'according', 'eucolait'])],
#  [WordList(['redistributing', 'better', 'export']),
#   WordList(['better', 'export', 'might']),
#   WordList(['export', 'might', 'help']),
#   WordList(['might', 'help', 'contribute']),
#   WordList(['help', 'contribute', 'security'])],
#  [WordList(['jukka', 'likitalo', 'secretary']),
#   WordList(['likitalo', 'secretary', 'general']),
#   WordList(['secretary', 'general', 'eucolait']),
#   WordList(['general', 'eucolait', 'tell']),
#   WordList(['eucolait', 'tell', 'foodingredientsfirst']),
#   WordList(['tell', 'foodingredientsfirst', '2023']),
#   WordList(['foodingredientsfirst', '2023', 'shaping']),
#   WordList(['2023', 'shaping', 'uncertain'])],
#  [WordList(['note', 'gone', 'last']),
#   WordList(['gone', 'last', 'month']),
#   WordList(['last', 'month', 'still']),
#   WordList(['month', 'still', 'uncertainty']),
#   WordList(['still', 'uncertainty', 'volatility']),
#   WordList(['uncertainty', 'volatility', 'ahead']),
#   WordList(['volatility', 'ahead', 'market'])],
#  [WordList(['sentiment', 'weakened', 'come']),
#   WordList(['weakened', 'come', 'considerably']),
#   WordList(['come', 'considerably', 'last']),
#   WordList(['considerably', 'last', 'month']),
#   WordList(['last', 'month', 'production']),
#   WordList(['month', 'production', 'stronger']),
#   WordList(['production', 'stronger', 'expected']),
#   WordList(['stronger', 'expected', 'question']),
#   WordList(['expected', 'question', 'mark']),
#   WordList(['question', 'mark', 'consumption']),
#   WordList(['mark', 'consumption', 'side']),
#   WordList(['consumption', 'side', 'due']),
#   WordList(['side', 'due', 'inflationary']),
#   WordList(['due', 'inflationary', 'pressure']),
#   WordList(['inflationary', 'pressure', 'economic']),
#   WordList(['pressure', 'economic', 'anxiety']),
#   WordList(['economic', 'anxiety', 'price']),
#   WordList(['anxiety', 'price', 'forecast']),
#   WordList(['price', 'forecast', 'feeling']),
#   WordList(['forecast', 'feeling', 'entered']),
#   WordList(['feeling', 'entered', 'new']),
#   WordList(['entered', 'new', 'era']),
#   WordList(['new', 'era', 'longer']),
#   WordList(['era', 'longer', 'available']),
#   WordList(['longer', 'available', 'abundance']),
#   WordList(['available', 'abundance', 'consumption']),
#   WordList(['abundance', 'consumption', 'continues']),
#   WordList(['consumption', 'continues', 'grow']),
#   WordList(['continues', 'grow', 'explains']),
#   WordList(['grow', 'explains', 'likitalo'])],
#  [WordList(['shortage', 'uncertainty', 'factor']),
#   WordList(['uncertainty', 'factor', 'however']),
#   WordList(['factor', 'however', 'energy']),
#   WordList(['however', 'energy', 'input']),
#   WordList(['energy', 'input', 'cost']),
#   WordList(['input', 'cost', 'generational']),
#   WordList(['cost', 'generational', 'renewal']),
#   WordList(['generational', 'renewal', 'farming']),
#   WordList(['renewal', 'farming', 'inflation']),
#   WordList(['farming', 'inflation', 'geopolitical']),
#   WordList(['inflation', 'geopolitical', 'development']),
#   WordList(['geopolitical', 'development', 'outlook']),
#   WordList(['development', 'outlook', 'main']),
#   WordList(['outlook', 'main', 'import']),
#   WordList(['main', 'import', 'market']),
#   WordList(['import', 'market', 'china']),
#   WordList(['market', 'china', 'environmental']),
#   WordList(['china', 'environmental', 'regulation']),
#   WordList(['environmental', 'regulation', 'changing']),
#   WordList(['regulation', 'changing', 'consumer']),
#   WordList(['changing', 'consumer', 'preference']),
#   WordList(['consumer', 'preference', 'name']),
#   WordList(['preference', 'name', 'continues'])],
#  [WordList(['likitalo', 'explains', 'must']),
#   WordList(['explains', 'must', 'sensible']),
#   WordList(['must', 'sensible', 'partner']),
#   WordList(['sensible', 'partner', 'future']),
#   WordList(['partner', 'future', 'avoid']),
#   WordList(['future', 'avoid', 'dependence']),
#   WordList(['avoid', 'dependence', 'unreliable']),
#   WordList(['dependence', 'unreliable', 'partner']),
#   WordList(['unreliable', 'partner', 'like']),
#   WordList(['partner', 'like', 'russia']),
#   WordList(['like', 'russia', 'work']),
#   WordList(['russia', 'work', 'much']),
#   WordList(['work', 'much', 'one']),
#   WordList(['much', 'one', 'big']),
#   WordList(['one', 'big', 'market']),
#   WordList(['big', 'market', 'china'])],
#  [WordList(['likitalo', 'explains', 'must']),
#   WordList(['explains', 'must', 'sensible']),
#   WordList(['must', 'sensible', 'partner']),
#   WordList(['sensible', 'partner', 'future']),
#   WordList(['partner', 'future', 'avoid']),
#   WordList(['future', 'avoid', 'dependence']),
#   WordList(['avoid', 'dependence', 'unreliable']),
#   WordList(['dependence', 'unreliable', 'partner']),
#   WordList(['unreliable', 'partner', 'like']),
#   WordList(['partner', 'like', 'russiawe']),
#   WordList(['like', 'russiawe', 'need']),
#   WordList(['russiawe', 'need', 'produce']),
#   WordList(['need', 'produce', 'morethe']),
#   WordList(['produce', 'morethe', 'body']),
#   WordList(['morethe', 'body', 'flag']),
#   WordList(['body', 'flag', 'consumption']),
#   WordList(['flag', 'consumption', 'inadequate']),
#   WordList(['consumption', 'inadequate', 'large']),
#   WordList(['inadequate', 'large', 'part']),
#   WordList(['large', 'part', 'world']),
#   WordList(['part', 'world', 'many']),
#   WordList(['world', 'many', 'cant']),
#   WordList(['many', 'cant', 'meet']),
#   WordList(['cant', 'meet', 'necessity']),
#   WordList(['meet', 'necessity', 'independently']),
#   WordList(['necessity', 'independently', 'prompt']),
#   WordList(['independently', 'prompt', 'need']),
#   WordList(['prompt', 'need', 'overall']),
#   WordList(['need', 'overall', 'production'])],
#  [WordList(['sustainable', 'system', 'us']),
#   WordList(['system', 'us', 'scarce']),
#   WordList(['us', 'scarce', 'natural']),
#   WordList(['scarce', 'natural', 'resource']),
#   WordList(['natural', 'resource', 'efficiently']),
#   WordList(['resource', 'efficiently', 'effectively']),
#   WordList(['efficiently', 'effectively', 'possible']),
#   WordList(['effectively', 'possible', 'face']),
#   WordList(['possible', 'face', 'dual']),
#   WordList(['face', 'dual', 'challenge']),
#   WordList(['dual', 'challenge', 'feeding']),
#   WordList(['challenge', 'feeding', 'growing']),
#   WordList(['feeding', 'growing', 'population']),
#   WordList(['growing', 'population', 'need']),
#   WordList(['population', 'need', 'produce']),
#   WordList(['need', 'produce', 'le']),
#   WordList(['produce', 'le', 'adapted']),
#   WordList(['le', 'adapted', 'security']),
#   WordList(['adapted', 'security', 'without']),
#   WordList(['security', 'without', 'open']),
#   WordList(['without', 'open', 'rulebased']),
#   WordList(['open', 'rulebased', 'body']),
#   WordList(['rulebased', 'body', 'explains'])],
#  [WordList(['enhanced', 'sustainability', 'european']),
#   WordList(['sustainability', 'european', 'sector']),
#   WordList(['european', 'sector', 'go']),
#   WordList(['sector', 'go', 'handinhand']),
#   WordList(['go', 'handinhand', 'declining']),
#   WordList(['handinhand', 'declining', 'output'])],
#  [WordList(['basic', 'essence', 'connects']),
#   WordList(['essence', 'connects', 'surplus']),
#   WordList(['connects', 'surplus', 'deficit']),
#   WordList(['surplus', 'deficit', 'help']),
#   WordList(['deficit', 'help', 'region']),
#   WordList(['help', 'region', 'play']),
#   WordList(['region', 'play', 'strength'])],
#  [WordList(['internally', 'likitalo', 'highlight']),
#   WordList(['likitalo', 'highlight', 'crucial']),
#   WordList(['highlight', 'crucial', 'security']),
#   WordList(['crucial', 'security', 'standpoint']),
#   WordList(['security', 'standpoint', 'single']),
#   WordList(['standpoint', 'single', 'market']),
#   WordList(['single', 'market', 'remains']),
#   WordList(['market', 'remains', 'operational']),
#   WordList(['remains', 'operational', 'crisis']),
#   WordList(['operational', 'crisis', 'situation']),
#   WordList(['crisis', 'situation', 'avoid']),
#   WordList(['situation', 'avoid', 'shortage']),
#   WordList(['avoid', 'shortage', 'supply']),
#   WordList(['shortage', 'supply', 'disparity'])],
#  [WordList(['riseeucolait', 'explains', 'despite']),
#   WordList(['explains', 'despite', 'international']),
#   WordList(['despite', 'international', 'economic']),
#   WordList(['international', 'economic', 'woe']),
#   WordList(['economic', 'woe', 'affect']),
#   WordList(['woe', 'affect', 'increased']),
#   WordList(['affect', 'increased', '27']),
#   WordList(['increased', '27', 'q3']),
#   WordList(['27', 'q3', 'however']),
#   WordList(['q3', 'however', '2022']),
#   WordList(['however', '2022', 'likely']),
#   WordList(['2022', 'likely', 'mark']),
#   WordList(['likely', 'mark', 'first']),
#   WordList(['mark', 'first', 'decline']),
#   WordList(['first', 'decline', 'cumulative']),
#   WordList(['decline', 'cumulative', 'volume']),
#   WordList(['cumulative', 'volume', 'two']),
#   WordList(['volume', 'two', 'decade']),
#   WordList(['two', 'decade', 'expected']),
#   WordList(['decade', 'expected', 'fall']),
#   WordList(['expected', 'fall', '23'])],
#  [WordList(['notably', 'weak', 'chinese']),
#   WordList(['weak', 'chinese', 'explains']),
#   WordList(['chinese', 'explains', 'fall']),
#   WordList(['explains', 'fall', 'internationally']),
#   WordList(['fall', 'internationally', 'nevertheless']),
#   WordList(['internationally', 'nevertheless', 'asian']),
#   WordList(['nevertheless', 'asian', 'dynamic']),
#   WordList(['asian', 'dynamic', 'led']),
#   WordList(['dynamic', 'led', 'indonesia']),
#   WordList(['led', 'indonesia', 'fastest']),
#   WordList(['indonesia', 'fastest', 'growing']),
#   WordList(['fastest', 'growing', 'market']),
#   WordList(['growing', 'market', 'world']),
#   WordList(['market', 'world', 'like']),
#   WordList(['world', 'like', 'saudi']),
#   WordList(['like', 'saudi', 'arabia']),
#   WordList(['saudi', 'arabia', 'philippine']),
#   WordList(['arabia', 'philippine', 'also']),
#   WordList(['philippine', 'also', 'stood']),
#   WordList(['also', 'stood', 'according']),
#   WordList(['stood', 'according', 'eucolait'])],
#  [WordList(['import', 'china', '20']),
#   WordList(['china', '20', 'yearonyear']),
#   WordList(['20', 'yearonyear', 'according']),
#   WordList(['yearonyear', 'according', 'agriculture']),
#   WordList(['according', 'agriculture', 'horticulture']),
#   WordList(['agriculture', 'horticulture', 'development']),
#   WordList(['horticulture', 'development', 'board']),
#   WordList(['development', 'board', 'ahbd']),
#   WordList(['board', 'ahbd', 'ahbd']),
#   WordList(['ahbd', 'ahbd', 'flag']),
#   WordList(['ahbd', 'flag', 'lower']),
#   WordList(['flag', 'lower', 'offered']),
#   WordList(['lower', 'offered', 'relief']),
#   WordList(['offered', 'relief', 'international']),
#   WordList(['relief', 'international', 'however']),
#   WordList(['international', 'however', 'producer']),
#   WordList(['however', 'producer', 'negatively']),
#   WordList(['producer', 'negatively', 'affected']),
#   WordList(['negatively', 'affected', 'saw']),
#   WordList(['affected', 'saw', 'fall']),
#   WordList(['saw', 'fall', 'export']),
#   WordList(['fall', 'export', 'asian']),
#   WordList(['export', 'asian', 'giant']),
#   WordList(['asian', 'giant', '31']),
#   WordList(['giant', '31', 'single'])],
#  [WordList(['commodity', 'dipin', 'uk']),
#   WordList(['dipin', 'uk', 'consumer']),
#   WordList(['uk', 'consumer', 'seeing']),
#   WordList(['consumer', 'seeing', 'annual']),
#   WordList(['seeing', 'annual', 'rise']),
#   WordList(['annual', 'rise', 'cpi']),
#   WordList(['rise', 'cpi', 'lowfat']),
#   WordList(['cpi', 'lowfat', '479']),
#   WordList(['lowfat', '479', 'un']),
#   WordList(['479', 'un', 'fao']),
#   WordList(['un', 'fao', 'price']),
#   WordList(['fao', 'price', 'index']),
#   WordList(['price', 'index', 'showed']),
#   WordList(['index', 'showed', '12']),
#   WordList(['showed', '12', 'decline']),
#   WordList(['12', 'decline', 'november']),
#   WordList(['decline', 'november', 'october']),
#   WordList(['november', 'october', 'declining']),
#   WordList(['october', 'declining', 'fifth']),
#   WordList(['declining', 'fifth', 'consecutive']),
#   WordList(['fifth', 'consecutive', 'month']),
#   WordList(['consecutive', 'month', 'however']),
#   WordList(['month', 'however', 'continue']),
#   WordList(['however', 'continue', '92']),
#   WordList(['continue', '92', 'higher']),
#   WordList(['92', 'higher', 'one']),
#   WordList(['higher', 'one', 'ago']),
#   WordList(['one', 'ago', 'driven']),
#   WordList(['ago', 'driven', 'inflationary']),
#   WordList(['driven', 'inflationary', 'pressure']),
#   WordList(['inflationary', 'pressure', 'earlier'])],
#  [WordList(['fao', 'say', 'increased']),
#   WordList(['say', 'increased', 'export']),
#   WordList(['increased', 'export', 'availability']),
#   WordList(['export', 'availability', 'europe'])],
#  [WordList(['nevertheless', 'consumer', 'paying']),
#   WordList(['consumer', 'paying', 'considerably']),
#   WordList(['paying', 'considerably', 'finished']),
#   WordList(['considerably', 'finished', 'product']),
#   WordList(['finished', 'product', 'store']),
#   WordList(['product', 'store', 'globally']),
#   WordList(['store', 'globally', '92']),
#   WordList(['globally', '92', 'commoditywise']),
#   WordList(['92', 'commoditywise', 'uk']),
#   WordList(['commoditywise', 'uk', 'consumer']),
#   WordList(['uk', 'consumer', 'seeing']),
#   WordList(['consumer', 'seeing', 'annual']),
#   WordList(['seeing', 'annual', 'rise']),
#   WordList(['annual', 'rise', 'cpi']),
#   WordList(['rise', 'cpi', 'lowfat']),
#   WordList(['cpi', 'lowfat', '479'])],
#  [WordList(['kerry', 'ireland', 'revealed']),
#   WordList(['ireland', 'revealed', 'q3']),
#   WordList(['revealed', 'q3', 'report']),
#   WordList(['q3', 'report', 'increased']),
#   WordList(['report', 'increased', '366']),
#   WordList(['increased', '366', 'first']),
#   WordList(['366', 'first', 'nine']),
#   WordList(['first', 'nine', 'month']),
#   WordList(['nine', 'month', 'significantly']),
#   WordList(['month', 'significantly', 'outpacing']),
#   WordList(['significantly', 'outpacing', 'general']),
#   WordList(['outpacing', 'general', 'pricing']),
#   WordList(['general', 'pricing', 'strategy']),
#   WordList(['pricing', 'strategy', 'giant']),
#   WordList(['strategy', 'giant', 'increased']),
#   WordList(['giant', 'increased', '106'])],
#  [WordList(['european', 'giant', 'frieslandcampinas']),
#   WordList(['giant', 'frieslandcampinas', 'beverage']),
#   WordList(['frieslandcampinas', 'beverage', 'business']),
#   WordList(['beverage', 'business', 'revealed']),
#   WordList(['business', 'revealed', 'halfyear']),
#   WordList(['revealed', 'halfyear', 'result']),
#   WordList(['halfyear', 'result', 'boosted']),
#   WordList(['result', 'boosted', 'high']),
#   WordList(['boosted', 'high', 'butter']),
#   WordList(['high', 'butter', 'market'])],
#  [WordList(['danishswedish', 'multinational', 'cooperative']),
#   WordList(['multinational', 'cooperative', 'arla']),
#   WordList(['cooperative', 'arla', 'food']),
#   WordList(['arla', 'food', 'increased']),
#   WordList(['food', 'increased', 'eight']),
#   WordList(['increased', 'eight', 'month']),
#   WordList(['eight', 'month', 'row']),
#   WordList(['month', 'row', 'december']),
#   WordList(['row', 'december', 'marking']),
#   WordList(['december', 'marking', 'first']),
#   WordList(['marking', 'first', 'month']),
#   WordList(['first', 'month', 'since']),
#   WordList(['month', 'since', 'march']),
#   WordList(['since', 'march', 'without']),
#   WordList(['march', 'without', 'price']),
#   WordList(['without', 'price', 'increase'])],
#  [WordList(['supply', 'level', 'continue']),
#   WordList(['level', 'continue', 'stabilize']),
#   WordList(['continue', 'stabilize', 'level']),
#   WordList(['stabilize', 'level', 'europe']),
#   WordList(['level', 'europe', 'increasing']),
#   WordList(['europe', 'increasing', 'commodity']),
#   WordList(['increasing', 'commodity', 'including']),
#   WordList(['commodity', 'including', 'yellow']),
#   WordList(['including', 'yellow', 'cheese']),
#   WordList(['yellow', 'cheese', 'butter']),
#   WordList(['cheese', 'butter', 'declined']),
#   WordList(['butter', 'declined', 'previous']),
#   WordList(['declined', 'previous', 'high']),
#   WordList(['previous', 'high', 'level']),
#   WordList(['high', 'level', 'october']),
#   WordList(['level', 'october', 'outlook']),
#   WordList(['october', 'outlook', 'negative']),
#   WordList(['outlook', 'negative', 'driven']),
#   WordList(['negative', 'driven', 'continued']),
#   WordList(['driven', 'continued', 'decline']),
#   WordList(['continued', 'decline', 'commodity']),
#   WordList(['decline', 'commodity', 'say']),
#   WordList(['commodity', 'say', 'arthur']),
#   WordList(['say', 'arthur', 'fearnall']),
#   WordList(['arthur', 'fearnall', 'arla']),
#   WordList(['fearnall', 'arla', 'food']),
#   WordList(['arla', 'food', 'board']),
#   WordList(['food', 'board', 'director'])],
#  [WordList(['last', 'brought', 'inflationary']),
#   WordList(['brought', 'inflationary', 'challenge']),
#   WordList(['inflationary', 'challenge', 'farmerowners']),
#   WordList(['challenge', 'farmerowners', 'team']),
#   WordList(['farmerowners', 'team', 'across']),
#   WordList(['team', 'across', 'uk']),
#   WordList(['across', 'uk', 'worked']),
#   WordList(['uk', 'worked', 'hard']),
#   WordList(['worked', 'hard', 'deliver']),
#   WordList(['hard', 'deliver', 'significant']),
#   WordList(['deliver', 'significant', 'increase']),
#   WordList(['significant', 'increase', 'conventional']),
#   WordList(['increase', 'conventional', 'organic']),
#   WordList(['conventional', 'organic', 'farmgate']),
#   WordList(['organic', 'farmgate', 'price']),
#   WordList(['farmgate', 'price', 'throughout']),
#   WordList(['price', 'throughout', 'add']),
#   WordList(['throughout', 'add', 'paul']),
#   WordList(['add', 'paul', 'savage']),
#   WordList(['paul', 'savage', 'agriculture']),
#   WordList(['savage', 'agriculture', 'director']),
#   WordList(['agriculture', 'director', 'arla']),
#   WordList(['director', 'arla', 'uk'])],
#  [WordList(['however', 'general', 'cheese']),
#   WordList(['general', 'cheese', 'previous']),
#   WordList(['cheese', 'previous', 'month']),
#   WordList(['previous', 'month', 'continues']),
#   WordList(['month', 'continues', 'outpace']),
#   WordList(['continues', 'outpace', 'formilk']),
#   WordList(['outpace', 'formilk', 'international']),
#   WordList(['formilk', 'international', 'cheese']),
#   WordList(['international', 'cheese', 'increased']),
#   WordList(['cheese', 'increased', 'underpinned']),
#   WordList(['increased', 'underpinned', 'steady']),
#   WordList(['underpinned', 'steady', 'import']),
#   WordList(['steady', 'import', 'le']),
#   WordList(['import', 'le', 'buoyant']),
#   WordList(['le', 'buoyant', 'export']),
#   WordList(['buoyant', 'export', 'availability']),
#   WordList(['export', 'availability', 'major']),
#   WordList(['availability', 'major', 'producing']),
#   WordList(['major', 'producing', 'western']),
#   WordList(['producing', 'western', 'europe']),
#   WordList(['western', 'europe', 'say']),
#   WordList(['europe', 'say', 'fao'])],
#  [WordList(['cheese', 'becoming', 'coveted']),
#   WordList(['becoming', 'coveted', 'commodity']),
#   WordList(['coveted', 'commodity', 'supermarket']),
#   WordList(['commodity', 'supermarket', 'uk']),
#   WordList(['supermarket', 'uk', 'putting']),
#   WordList(['uk', 'putting', 'security']),
#   WordList(['putting', 'security', 'tag']),
#   WordList(['security', 'tag', 'cheese']),
#   WordList(['tag', 'cheese', 'butter']),
#   WordList(['cheese', 'butter', 'product'])],
#  [],
#  [WordList(['contact', 'editorial', 'team']),
#   WordList(['editorial', 'team', 'please']),
#   WordList(['team', 'please', 'email']),
#   WordList(['please', 'email', 'u']),
#   WordList(['email', 'u', 'editorialcnsmediacom'])],
#  [],
#  [WordList(['corruption', 'court', 'central']),
#   WordList(['court', 'central', 'jakarta']),
#   WordList(['central', 'jakarta', 'district']),
#   WordList(['jakarta', 'district', 'court']),
#   WordList(['district', 'court', 'sentenced']),
#   WordList(['court', 'sentenced', 'former']),
#   WordList(['sentenced', 'former', 'director']),
#   WordList(['former', 'director', 'general']),
#   WordList(['director', 'general', 'ministry']),
#   WordList(['general', 'ministry', 'head']),
#   WordList(['ministry', 'head', 'country']),
#   WordList(['head', 'country', 'commodity']),
#   WordList(['country', 'commodity', 'read'])],
#  [WordList(['inflation', 'one', 'significant']),
#   WordList(['one', 'significant', 'topic']),
#   WordList(['significant', 'topic', '2023']),
#   WordList(['topic', '2023', 'get']),
#   WordList(['2023', 'get', 'underway']),
#   WordList(['get', 'underway', 'underscored']),
#   WordList(['underway', 'underscored', 'latest']),
#   WordList(['underscored', 'latest', 'data']),
#   WordList(['latest', 'data', 'uk']),
#   WordList(['data', 'uk', 'reveals']),
#   WordList(['uk', 'reveals', 'annual']),
#   WordList(['reveals', 'annual', 'growth']),
#   WordList(['annual', 'growth', 'britain']),
#   WordList(['growth', 'britain', 'read'])],
#  [WordList(['partnership', 'agriculture', 'organization']),
#   WordList(['agriculture', 'organization', 'united']),
#   WordList(['organization', 'united', 'nation']),
#   WordList(['united', 'nation', 'fao']),
#   WordList(['nation', 'fao', 'provide']),
#   WordList(['fao', 'provide', 'us155']),
#   WordList(['provide', 'us155', 'million']),
#   WordList(['us155', 'million', 'ensure']),
#   WordList(['million', 'ensure', 'support']),
#   WordList(['ensure', 'support', 'ukrainian']),
#   WordList(['support', 'ukrainian', 'read'])],
#  [WordList(['china', 'relax', 'testing']),
#   WordList(['relax', 'testing', 'imported']),
#   WordList(['testing', 'imported', 'frozen']),
#   WordList(['imported', 'frozen', 'chilled']),
#   WordList(['frozen', 'chilled', 'product']),
#   WordList(['chilled', 'product', 'lowering']),
#   WordList(['product', 'lowering', 'cost']),
#   WordList(['lowering', 'cost', 'exporter']),
#   WordList(['cost', 'exporter', 'confirmed']),
#   WordList(['exporter', 'confirmed', 'country']),
#   WordList(['confirmed', 'country', 'custom']),
#   WordList(['country', 'custom', 'authority']),
#   WordList(['custom', 'authority', 'state']),
#   WordList(['authority', 'state', 'read'])],
#  [WordList(['2023', 'begin', 'continue']),
#   WordList(['begin', 'continue', 'attempt']),
#   WordList(['continue', 'attempt', 'tame']),
#   WordList(['attempt', 'tame', 'inflation']),
#   WordList(['tame', 'inflation', 'spain']),
#   WordList(['inflation', 'spain', 'u']),
#   WordList(['spain', 'u', 'state']),
#   WordList(['u', 'state', 'reducing']),
#   WordList(['state', 'reducing', 'vat']),
#   WordList(['reducing', 'vat', 'tax']),
#   WordList(['vat', 'tax', 'sacrificing']),
#   WordList(['tax', 'sacrificing', 'potential']),
#   WordList(['sacrificing', 'potential', 'tax']),
#   WordList(['potential', 'tax', 'revenue']),
#   WordList(['tax', 'revenue', 'aiming']),
#   WordList(['revenue', 'aiming', 'read'])],
#  [WordList(['foodingredientsfirstcom', 'leading', 'international']),
#   WordList(['leading', 'international', 'publisher']),
#   WordList(['international', 'publisher', 'ingredient']),
#   WordList(['publisher', 'ingredient', 'product']),
#   WordList(['ingredient', 'product', 'development']),
#   WordList(['product', 'development', 'platform']),
#   WordList(['development', 'platform', 'hosted']),
#   WordList(['platform', 'hosted', 'cns']),
#   WordList(['hosted', 'cns', 'medium']),
#   WordList(['cns', 'medium', 'bv']),
#   WordList(['medium', 'bv', 'arnhem'])]]

# %% [markdown]
# ## 1.12 Term frequency
# **This step does the ratio of the count of a word present in a sentence, to the length of the sentence.**
#
# TF = (Number of times term T appears in the particular row) / (number of terms in that row)

# %%
tf1 = (text['paragraph'][0:37]).apply(lambda x: pd.value_counts(x.split(" "))).sum(axis = 0).reset_index()
tf1.columns = ['words','tf']
tf1
# Out:
#           words   tf
# 0         agree  2.0
# 1       privacy  2.0
# 2        cookie  2.0
# 3        policy  2.0
# 4    continuing  1.0
# ..          ...  ...
# 416      hosted  1.0
# 417         cns  1.0
# 418      medium  1.0
# 419          bv  1.0
# 420      arnhem  1.0
#
# [421 rows x 2 columns]

# %% [markdown]
# ## 1.13 Inverse Document Frequency
# **Inverse document frequency (IDF) is tries to prove that a word is not of much use if it is appearing in all the documents**
#
# IDF = log(N/n), where, N is the total number of rows and n is the number of rows in which the word was present.

# %%
#The more the value of IDF, the more unique is the word.
for i,word in enumerate(tf1['words']):
    tf1.loc[i, 'idf'] = np.log(text.shape[0]/(len(text[text['paragraph'].str.contains(word)])))

tf1.head()
# Out:
#         words   tf       idf
# 0       agree  2.0  3.610918
# 1     privacy  2.0  3.610918
# 2      cookie  2.0  3.610918
# 3      policy  2.0  3.610918
# 4  continuing  1.0  3.610918

# %% [markdown]
# ### 1.14 Term Frequency – Inverse Document Frequency (TF-IDF)

# %%
#TF-IDF is the multiplication of the TF and IDF which we calculated above
tf1['tfidf'] = tf1['tf'] * tf1['idf']
tf1
# Out:
#           words   tf       idf     tfidf
# 0         agree  2.0  3.610918  7.221836
# 1       privacy  2.0  3.610918  7.221836
# 2        cookie  2.0  3.610918  7.221836
# 3        policy  2.0  3.610918  7.221836
# 4    continuing  1.0  3.610918  3.610918
# ..          ...  ...       ...       ...
# 416      hosted  1.0  3.610918  3.610918
# 417         cns  1.0  2.917771  2.917771
# 418      medium  1.0  3.610918  3.610918
# 419          bv  1.0  3.610918  3.610918
# 420      arnhem  1.0  3.610918  3.610918
#
# [421 rows x 4 columns]

# %%
# There is no need to calculate TF and IDF every time beforehand and then multiply it to obtain TF-IDF. 
# Instead, sklearn has a separate function to directly obtain it: 

tfidf = TfidfVectorizer(max_features=1000, lowercase=True, analyzer='word',
stop_words= 'english',ngram_range=(1,1))
text_vect = tfidf.fit_transform(text['paragraph'])

text_vect
# Out:
# <37x387 sparse matrix of type '<class 'numpy.float64'>'
# 	with 565 stored elements in Compressed Sparse Row format>

# %%
print(text_vect)
# Out:
#   (0, 264)	0.4588314677411236
#   (0, 80)	0.4588314677411236
#   (0, 274)	0.4588314677411236
#   (0, 19)	0.4588314677411236
#   (0, 332)	0.2294157338705618
#   (0, 49)	0.2294157338705618
#   (0, 77)	0.2294157338705618
#   (1, 363)	0.18989805657191236
#   (1, 377)	0.18989805657191236
#   (1, 247)	0.18989805657191236
#   (1, 326)	0.18989805657191236
#   (1, 56)	0.18989805657191236
#   (1, 193)	0.14578485564351867
#   (1, 286)	0.18989805657191236
#   (1, 174)	0.18989805657191236
#   (1, 267)	0.18989805657191236
#   (1, 166)	0.18989805657191236
#   (1, 334)	0.18989805657191236
#   (1, 359)	0.18989805657191236
#   (1, 224)	0.12315736001057263
#   (1, 156)	0.18989805657191236
#   (1, 316)	0.17037765419171577
#   (1, 24)	0.18989805657191236
#   (1, 347)	0.29156971128703735
#   (1, 325)	0.18989805657191236
#   :	:
#   (35, 355)	0.4812126319882611
#   (35, 374)	0.24060631599413054
#   (35, 290)	0.24060631599413054
#   (35, 336)	0.24060631599413054
#   (35, 353)	0.24060631599413054
#   (35, 32)	0.24060631599413054
#   (35, 38)	0.24060631599413054
#   (35, 339)	0.21587340303962882
#   (35, 287)	0.1735922090758954
#   (35, 74)	0.19832512203039715
#   (35, 5)	0.19832512203039715
#   (35, 193)	0.1847136178080894
#   (36, 29)	0.29281438604340576
#   (36, 53)	0.29281438604340576
#   (36, 226)	0.29281438604340576
#   (36, 63)	0.29281438604340576
#   (36, 180)	0.29281438604340576
#   (36, 262)	0.29281438604340576
#   (36, 282)	0.29281438604340576
#   (36, 208)	0.29281438604340576
#   (36, 153)	0.29281438604340576
#   (36, 195)	0.2627147908107765
#   (36, 278)	0.2247937855199587
#   (36, 198)	0.2247937855199587
#   (36, 104)	0.2413587881281176

# %% [markdown]
# ## 1.15 Bag of Words
# **This is the representation of text which describes the presence of words within the text data. The idea behThis helps in understanding the meaning of the document.**

# %%
bow = CountVectorizer(max_features=1000, lowercase=True, ngram_range=(1,1),analyzer = "word")
text_bow = bow.fit_transform(text['paragraph'])
text_bow
# Out:
# <37x420 sparse matrix of type '<class 'numpy.int64'>'
# 	with 612 stored elements in Compressed Sparse Row format>

# %%
print(text_bow)
# Out:
#   (0, 82)	1
#   (0, 52)	1
#   (0, 357)	1
#   (0, 20)	2
#   (0, 297)	2
#   (0, 85)	2
#   (0, 287)	2
#   (1, 2)	1
#   (1, 99)	1
#   (1, 4)	1
#   (1, 136)	1
#   (1, 389)	1
#   (1, 48)	1
#   (1, 134)	1
#   (1, 398)	1
#   (1, 246)	1
#   (1, 254)	1
#   (1, 46)	1
#   (1, 348)	1
#   (1, 373)	2
#   (1, 25)	1
#   (1, 339)	1
#   (1, 406)	1
#   (1, 165)	1
#   (1, 238)	1
#   :	:
#   (35, 364)	1
#   (35, 41)	1
#   (35, 34)	1
#   (35, 380)	1
#   (35, 361)	1
#   (35, 313)	1
#   (35, 405)	1
#   (35, 382)	2
#   (35, 333)	1
#   (35, 291)	1
#   (35, 326)	1
#   (35, 24)	1
#   (36, 109)	1
#   (36, 210)	1
#   (36, 301)	1
#   (36, 207)	1
#   (36, 161)	1
#   (36, 221)	1
#   (36, 305)	1
#   (36, 284)	1
#   (36, 191)	1
#   (36, 68)	1
#   (36, 240)	1
#   (36, 56)	1
#   (36, 31)	1

# %% [markdown]
# # 2 Final Sentimental Analysis
# **Concluding the problem of detecting the sentiment of the article and before applying any ML/DL models let’s check the sentiment of the first few paragraphs.**

# %%
text['paragraph'].apply(lambda x: TextBlob(x).sentiment)
# Out:
# 0                                       (0.0, 0.0)
# 2       (0.13333333333333333, 0.35000000000000003)
# 4                                       (0.4, 1.0)
# 5      (-0.03571428571428571, 0.12142857142857143)
# 6                                       (0.5, 0.5)
# 7                       (0.05000000000000002, 0.5)
# 8                       (0.0, 0.06666666666666667)
# 9       (0.08522727272727272, 0.31603535353535356)
# 10       (0.16666666666666666, 0.3333333333333333)
# 11       (0.06666666666666667, 0.1416666666666667)
# 12       (0.14285714285714285, 0.2357142857142857)
# 13       (0.03333333333333333, 0.6333333333333333)
# 14                                      (0.0, 0.0)
# 15                                    (0.0, 0.125)
# 16     (-0.023809523809523808, 0.4047619047619047)
# 17       (0.06999999999999999, 0.3866666666666666)
# 18                   (-0.075, 0.15833333333333333)
# 19     (-0.07428571428571429, 0.32285714285714284)
# 20                                    (0.125, 0.5)
# 21                                      (0.0, 0.0)
# 22                                   (0.05, 0.225)
# 23                   (0.16875, 0.6770833333333333)
# 24       (0.05333333333333334, 0.5133333333333333)
# 25                      (0.25, 0.3333333333333333)
# 26      (-0.07666666666666666, 0.2766666666666666)
# 27    (-0.014880952380952384, 0.46011904761904765)
# 28     (0.018750000000000003, 0.27777777777777773)
# 29                      (0.45, 0.8500000000000001)
# 30                                      (0.0, 0.0)
# 31                                      (0.0, 0.0)
# 32                                      (0.0, 0.0)
# 33                    (0.016666666666666673, 0.25)
# 35                                (0.4375, 0.8875)
# 37                                      (0.0, 0.0)
# 39                                      (0.4, 1.0)
# 41      (-0.10833333333333334, 0.6083333333333334)
# 46                                      (0.0, 0.0)
# Name: paragraph, dtype: object

# %% [markdown]
# **Above, we should only extract polarity as it indicates the sentiment as value nearer to 1 means a
# positive sentiment and values nearer to -1 means a negative sentiment. This can also work as
# a feature for building a machine learning model.**

# %%
text['sentiment'] = text['paragraph'].apply(lambda x: TextBlob(x).sentiment[0] )
text[['paragraph','sentiment']].tail()
# Out:
#                                             paragraph  sentiment
# 35  inflation one significant topic 2023 get under...   0.437500
# 37  partnership agriculture organization united na...   0.000000
# 39  china relax testing imported frozen chilled pr...   0.400000
# 41  2023 begin continue attempt tame inflation spa...  -0.108333
# 46  foodingredientsfirstcom leading international ...   0.000000

# %% [markdown]
# ## 2.1 Final Score

# %%
#We calcule the mean to check if our article is positive of negative, in this case it is positive
text['sentiment'].mean()
# Out:
# 0.08674037674037674

# %% [markdown]
# ### Conclusion: as the result is between -1 and 1 and it is greather than 0, we conclude the article is POSITIVE
